# %%
import os
import json
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import requests
import datetime as dt # to put a datestamp on the outputs
from pprint import pprint
from scipy.stats import linregress
import warnings
warnings.filterwarnings('ignore')


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../Resources/census.csv"

# %%
df = pd.read_csv("census.csv")
df.head()
# Out:
#    Unnamed: 0               Metro Area  2012 Pop  2012 Household Income  \
# 0           0  Aberdeen, SD Micro Area     40612                  49652
# 1           1  Aberdeen, WA Micro Area     72272                  42440
# 2           2   Abilene, TX Metro Area    165083                  44007
# 3           3       Ada, OK Micro Area     37438                  40680
# 4           4  Adjuntas, PR Micro Area     19458                  13095
#
#    2017 Pop  2017 Household Income
# 0     42608                  54533
# 1     71454                  45483
# 2    169000                  48156
# 3     38289                  46689
# 4     18525                  11680

# %%
df["Pop Growth"] = df['2017 Pop'] - df['2012 Pop']
df["Income Growth"] = df['2017 Household Income'] - df['2012 Household Income']
df.head()
# Out:
#    Unnamed: 0               Metro Area  2012 Pop  2012 Household Income  \
# 0           0  Aberdeen, SD Micro Area     40612                  49652
# 1           1  Aberdeen, WA Micro Area     72272                  42440
# 2           2   Abilene, TX Metro Area    165083                  44007
# 3           3       Ada, OK Micro Area     37438                  40680
# 4           4  Adjuntas, PR Micro Area     19458                  13095
#
#    2017 Pop  2017 Household Income  Pop Growth  Income Growth
# 0     42608                  54533        1996           4881
# 1     71454                  45483        -818           3043
# 2    169000                  48156        3917           4149
# 3     38289                  46689         851           6009
# 4     18525                  11680        -933          -1415

# %%
df["Pop Growth %"] = (df['Pop Growth']/df['2017 Pop'])*100
df["Income Growth %"] = (df['Income Growth']/df['2012 Household Income'])*100
df.style.format({"Pop Growth %":"{:,.2f}",
                "Income Growth %": "{:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Unnamed: 0</th>        <th class="col_heading level0 col1" >Metro Area</th>        <th class="col_heading level0 col2" >2012 Pop</th>        <th class="col_heading level0 col3" >2012 Household Income</th>        <th class="col_heading level0 col4" >2017 Pop</th>        <th class="col_heading level0 col5" >2017 Household Income</th>        <th class="col_heading level0 col6" >Pop Growth</th>        <th class="col_heading level0 col7" >Income Growth</th>        <th class="col_heading level0 col8" >Pop Growth %</th>        <th class="col_heading level0 col9" >Income Growth %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col1" class="data row0 col1" >Aberdeen, SD Micro Area</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col2" class="data row0 col2" >40612</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col3" class="data row0 col3" >49652</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col4" class="data row0 col4" >42608</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col5" class="data row0 col5" >54533</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col6" class="data row0 col6" >1996</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col7" class="data row0 col7" >4881</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col8" class="data row0 col8" >4.68</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row0_col9" class="data row0 col9" >9.83</td>
#             </tr>
#             <tr>
#                         <th id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col1" class="data row1 col1" >Aberdeen, WA Micro Area</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col2" class="data row1 col2" >72272</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col3" class="data row1 col3" >42440</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col4" class="data row1 col4" >71454</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col5" class="data row1 col5" >45483</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col6" class="data row1 col6" >-818</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col7" class="data row1 col7" >3043</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col8" class="data row1 col8" >-1.14</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row1_col9" class="data row1 col9" >7.17</td>
#             </tr>
#             <tr>
#                         <th id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col1" class="data row2 col1" >Abilene, TX Metro Area</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col2" class="data row2 col2" >165083</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col3" class="data row2 col3" >44007</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col4" class="data row2 col4" >169000</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col5" class="data row2 col5" >48156</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col6" class="data row2 col6" >3917</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col7" class="data row2 col7" >4149</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col8" class="data row2 col8" >2.32</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row2_col9" class="data row2 col9" >9.43</td>
#             </tr>
#             <tr>
#                         <th id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col1" class="data row3 col1" >Ada, OK Micro Area</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col2" class="data row3 col2" >37438</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col3" class="data row3 col3" >40680</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col4" class="data row3 col4" >38289</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col5" class="data row3 col5" >46689</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col6" class="data row3 col6" >851</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col7" class="data row3 col7" >6009</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col8" class="data row3 col8" >2.22</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row3_col9" class="data row3 col9" >14.77</td>
#             </tr>
#             <tr>
#                         <th id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col1" class="data row4 col1" >Adjuntas, PR Micro Area</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col2" class="data row4 col2" >19458</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col3" class="data row4 col3" >13095</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col4" class="data row4 col4" >18525</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col5" class="data row4 col5" >11680</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col6" class="data row4 col6" >-933</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col7" class="data row4 col7" >-1415</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col8" class="data row4 col8" >-5.04</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row4_col9" class="data row4 col9" >-10.81</td>
#             </tr>
#             <tr>
#                         <th id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row5_col1" class="data row5 col1" >Adrian, MI Micro Area</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_302432920544row5_col2" class="data row5 col2" >99878</td>
#                         <td id="T_3a3d91ba_e3b2_11e9_9f6b_3024

# %%
New_df = df.loc[(df['2017 Pop']>=200000)].drop(['Unnamed: 0'], axis  =1 )
New_df.head()
# Out:
#                                       Metro Area  2012 Pop  \
# 6                           Akron, OH Metro Area    702966
# 9         Albany-Schenectady-Troy, NY Metro Area    870890
# 13                    Albuquerque, NM Metro Area    885683
# 18  Allentown-Bethlehem-Easton, PA-NJ Metro Area    821273
# 23                       Amarillo, TX Metro Area    250224
#
#     2012 Household Income  2017 Pop  2017 Household Income  Pop Growth  \
# 6                   49936    703398                  53418         432
# 9                   60841    881862                  65743       10972
# 13                  48990    905049                  50781       19366
# 18                  58111    832790                  62479       11517
# 23                  47866    261827                  53665       11603
#
#     Income Growth  Pop Growth %  Income Growth %
# 6            3482      0.061416         6.972925
# 9            4902      1.244186         8.057067
# 13           1791      2.139774         3.655848
# 18           4368      1.382942         7.516649
# 23           5799      4.431552        12.115071

# %%
New_df.to_csv("Census_N.csv")

# %%
#Rank Cities by Population and Income Growth, add up their score, sort, re-index

New_df["Population Rank"] = New_df["Pop Growth %"].rank() 
New_df["Income Rank"] = New_df["Income Growth %"].rank() 
New_df["Total Score"] = New_df["Income Rank"] + New_df["Population Rank"]
New_df.sort_values(["Total Score"], ascending=[False], inplace = True)
New_df.reset_index(drop=True,inplace=True)
New_df.head()
# Out:
#                                           Metro Area  2012 Pop  \
# 0                Grand Rapids-Wyoming, MI Metro Area    777159
# 1                             Greeley, CO Metro Area    253552
# 2            Huntington-Ashland, WV-KY-OH Metro Area    287234
# 3  Nashville-Davidson--Murfreesboro--Franklin, TN...   1595454
# 4                            Fargo, ND-MN Metro Area    209177
#
#    2012 Household Income  2017 Pop  2017 Household Income  Pop Growth  \
# 0                  50491   1039182                  58094      262023
# 1                  56589    285729                  66489       32177
# 2                  38797    360603                  44315       73369
# 3                  52779   1830410                  59365      234956
# 4                  51411    232660                  59074       23483
#
#    Income Growth  Pop Growth %  Income Growth %  Population Rank  Income Rank  \
# 0           7603     25.214351        15.058129            163.0        161.0
# 1           9900     11.261370        17.494566            153.0        165.0
# 2           5518     20.346198        14.222749            160.0        158.0
# 3           6586     12.836250        12.478448            156.0        153.0
# 4           7663     10.093269        14.905370            147.0        160.0
#
#    Total Score
# 0        324.0
# 1        318.0
# 2        318.0
# 3        309.0
# 4        307.0
