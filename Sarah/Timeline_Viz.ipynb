# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Timeline_df = pd.read_csv("Resources\Resources\combined.csv")
Timeline_df.head()
# Out:
#          Week  Chipotle  Five Guys  Halal Guys  McDonalds  Panera Bread  \
# 0   9/24/2017        65         73          74         55            88
# 1   10/1/2017        66         75          74         75            87
# 2   10/8/2017        61         75          71         65            91
# 3  10/15/2017        64         79          79         57            90
# 4  10/22/2017        67         77          75         57            91
#
#    Shake Shack  Taco Bell  Texas Roadhouse
# 0           46         61               48
# 1           46         68               47
# 2          100         66               48
# 3           60         62               48
# 4           53         64               47

# %%
Timeline_df.dtypes
# Out:
# Week               object
# Chipotle            int64
# Five Guys           int64
# Halal Guys          int64
# McDonalds           int64
# Panera Bread        int64
# Shake Shack         int64
# Taco Bell           int64
# Texas Roadhouse     int64
# dtype: object

# %%
x_axis = np.arange(len(Timeline_df))
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'Chipotle', data=Timeline_df, color='black')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of Chipotle", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/Chipotle_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'Five Guys', data=Timeline_df, color='red')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of Five Guys", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/FiveGuys_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'Halal Guys', data=Timeline_df, color='pink')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of Halal Guys", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/HalalGuys_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'McDonalds', data=Timeline_df, color='yellow')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of McDonalds", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/McDonalds_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'Panera Bread', data=Timeline_df, color='brown')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of Panera Bread", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/PaneraBread_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'Shake Shack', data=Timeline_df, color='green')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of Shake Shack", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/ShakeShack_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'Taco Bell', data=Timeline_df, color='purple')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of Taco Bell", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/TacoBell_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
plt.figure(figsize=(16,5), dpi= 80)
plt.plot('Week', 'Texas Roadhouse', data=Timeline_df, color='orange')
Timeline_df.plot(ax=ax)
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Format
plt.ylim(0, 150)
xtick_location = Timeline_df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in Timeline_df.Week.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Popularity of Texas Roadhouse", fontsize=22)
plt.xlabel('Time period')
plt.ylabel('Rate of Popularity ')
plt.grid(axis='both', alpha=.3)
plt.savefig("Output Plots/TexasRoadhouse_Timeline.png")
# Out:
# <img src="data:image/png;base64,..." width="1280">
